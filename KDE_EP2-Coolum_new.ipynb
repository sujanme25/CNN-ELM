# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from scipy import integrate
from scipy.special import ndtr
# %matplotlib inline
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.distributions.mixture_rvs import mixture_rvs
from scipy.stats import zscore
import PIINTERVAL
import pandas as pd
import os
upper_bound = 0.975# 0.975/0.025(95),0.95/0.05(90),0.925/0.075(85),0.9/0.1(80),0.875/0.125(75),0.85/0.15(70)
lower_bound = 0.025

# %%
os.chdir('C:\\Users\\SUJAN\\OneDrive\\Documents\\Energies\\EP2\\KDE')
df1=pd.read_excel('EP2_SIM_OBS.xlsx',"Coolum")

# %%
df1

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['CELM']
df2['RES']=df1['YTEST']-df1['CELM']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_CELM=df5.copy()
y_test1=df_CELM['TEST'].values
y_test=df_CELM['TEST'].values
y_upper_TNET=df_CELM['UPPER'].values
y_lower_TNET= df_CELM['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_CELM=pd.DataFrame(PIM_TNET)
dfPIM_CELM

# %%
df_CELM=df5.copy()
df_CELM

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['DNN']
df2['RES']=df1['YTEST']-df1['DNN']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_DNN=df5.copy()
y_test1=df_DNN['TEST'].values
y_test=df_DNN['TEST'].values
y_upper_TNET=df_DNN['UPPER'].values
y_lower_TNET= df_DNN['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_DNN=pd.DataFrame(PIM_TNET)
dfPIM_DNN

# %%
df_DNN=df5.copy()
df_DNN

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['RFR']
df2['RES']=df1['YTEST']-df1['RFR']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_RFR=df5.copy()
y_test1=df_RFR['TEST'].values
y_test=df_RFR['TEST'].values
y_upper_TNET=df_RFR['UPPER'].values
y_lower_TNET= df_RFR['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_RFR=pd.DataFrame(PIM_TNET)
dfPIM_RFR

# %%
df_RFR=df5.copy()
df_RFR

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['SVR']
df2['RES']=df1['YTEST']-df1['SVR']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_SVR=df5.copy()
y_test1=df_SVR['TEST'].values
y_test=df_SVR['TEST'].values
y_upper_TNET=df_SVR['UPPER'].values
y_lower_TNET= df_SVR['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_SVR=pd.DataFrame(PIM_TNET)
dfPIM_SVR

# %%
df_SVR=df5.copy()
df_SVR

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['LSTM']
df2['RES']=df1['YTEST']-df1['LSTM']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_LSTM=df5.copy()
y_test1=df_LSTM['TEST'].values
y_test=df_LSTM['TEST'].values
y_upper_TNET=df_LSTM['UPPER'].values
y_lower_TNET= df_LSTM['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_LSTM=pd.DataFrame(PIM_TNET)
dfPIM_LSTM

# %%
df_LSTM=df5.copy()
df_LSTM

# %%
df2=pd.DataFrame()
df2['TEST']=df1['YTEST']
df2['PRED']=df1['KNNR']
df2['RES']=df1['YTEST']-df1['KNNR']
df5=df2.copy()
muR=df5['RES'].mean()
sigR=df5['RES'].std()
df5['NR'] = zscore(df5['RES'])
kde = sm.nonparametric.KDEUnivariate(df5['NR'])
kde.fit(bw='silverman')
A1=kde.support
B1=kde.cdf
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.cdf, lw=3, label="CDF")
list = zip(B1, A1)
df = pd.DataFrame(list, columns=('cdf', 'R1'))
A=np.interp(lower_bound, df.cdf, df.R1)
B=np.interp(upper_bound, df.cdf, df.R1)
YU=df5['PRED']+(B*sigR+muR)
YL=df5['PRED']+(A*sigR+muR)
df5['LOWER']=YL
df5['UPPER']=YU
df_KNNR=df5.copy()
y_test1=df_KNNR['TEST'].values
y_test=df_KNNR['TEST'].values
y_upper_TNET=df_KNNR['UPPER'].values
y_lower_TNET= df_KNNR['LOWER'].values
((y_test1 > y_upper_TNET).sum() + (y_test1 < y_lower_TNET).sum()) / y_test.shape[0]
pd.options.display.float_format = "{:,.3f}".format
act_range = max(y_test1)-min(y_test1)
confidence = 1 - (upper_bound - lower_bound)
PICP=PIINTERVAL.picp(y_test1, y_upper_TNET, y_lower_TNET)
MPIW = PIINTERVAL.mpiw( y_upper_TNET,y_lower_TNET)
WSSV=PIINTERVAL.WS(y_upper_TNET, y_lower_TNET, y_test1, confidence)
ARILV=PIINTERVAL.ARIL(y_test1, y_upper_TNET , y_lower_TNET)
PINAWV=PIINTERVAL.PINAW(act_range, y_upper_TNET , y_lower_TNET)
ACEV=PICP/100-(upper_bound-lower_bound)
F=(2*PICP/PINAWV)/(PICP+1/PINAWV)
PIM_TNET=[PICP,MPIW,WSSV,ARILV,PINAWV,ACEV,F]
PIM_TNET= pd.DataFrame(PIM_TNET).T
PIM_TNET.columns=['PICP','MPIW','WSSV','ARILV','PINAWV','ACEV','F']
dfPIM_KNNR=pd.DataFrame(PIM_TNET)
dfPIM_KNNR

# %%
df_KNNR=df5.copy()
df_KNNR

# %%
PIALL_Coolum=pd.concat([dfPIM_KNNR,dfPIM_RFR,dfPIM_CELM,dfPIM_DNN,dfPIM_SVR,dfPIM_LSTM],axis=0)
PIALL_Coolum.index = ['KNNR','RFR','CELM','DNN','SVR','LSTM']
PIALL_Coolum =PIALL_Coolum.sort_values(['MPIW'],ascending=[True])
PIALL_Coolum

# %%
import os
writer = pd.ExcelWriter('EP2_LU_Coolum.xlsx', engine='xlsxwriter')
df_CELM.to_excel(writer, sheet_name='CELM')
df_DNN.to_excel(writer, sheet_name='DNN')
df_LSTM.to_excel(writer, sheet_name='LSTM')
df_RFR.to_excel(writer, sheet_name='RFR')
df_SVR.to_excel(writer, sheet_name='SVR')
df_KNNR.to_excel(writer, sheet_name='KNNR')
# Close the Pandas Excel writer and output the Excel file.
writer.save()
